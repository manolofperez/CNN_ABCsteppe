# %% [markdown]
# # **Script and outputs for training and calibrating a CNN for model selection, perform cross-validation and predict the most likely model from empirical data in the species *Euphorbia segueriana* (scripts for the remaining species are similar).**
# From the manuscript Kirschner & Perez et al. "Congruent evolutionary responses of European steppe biota to late Quaternary climate change: insights from convolutional neural network-based demographic modeling".

# %%
# Import all required modules.
import sys, os
import numpy as np
import time
import random
from random import shuffle, choice
import keras
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.regularizers import l2
from tensorflow.keras.constraints import max_norm
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import backend as K
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.models import load_model
from keras.utils import np_utils
from sklearn.calibration import CalibratedClassifierCV
from sklearn.calibration import calibration_curve
import sklearn.metrics as metrics
from sklearn.metrics import log_loss
from sklearn.metrics import confusion_matrix

# Define parameters for the CNN run.
batch_size = 500
epochs = 500
num_classes = 3

# Define the CNN architecture.
def create_cnn(xtest):
	#use different filter sizes.
	filters = [3,5,20,50]
	inputShape = (xtest.shape[1], xtest.shape[2])
	inputs = Input(shape=inputShape)
	x = inputs
	x = Conv1D(250, kernel_size=2, activation='relu',input_shape=(xtest.shape[1], xtest.shape[2]))(x)
	x = BatchNormalization()(x)
	for f in range(len(filters)):
		x = Conv1D(20, kernel_size=filters[f], activation='relu',kernel_constraint=max_norm(3), bias_constraint=max_norm(3))(x)
		x = BatchNormalization()(x)
	x = Conv1D(125, kernel_size=2, activation='relu',kernel_constraint=max_norm(3), bias_constraint=max_norm(3))(x)
	x = BatchNormalization()(x)
	x = Conv1D(125, kernel_size=2, activation='relu',kernel_constraint=max_norm(3), bias_constraint=max_norm(3))(x)
	x = AveragePooling1D(pool_size=2)(x)
	x = Flatten()(x)
	x = Dense(125, activation='relu',kernel_regularizer=l2(1e-3), bias_regularizer=l2(1e-3))(x)
	x = Dropout(0.5)(x)
	x = Dense(125, activation='relu',kernel_regularizer=l2(1e-3), bias_regularizer=l2(1e-3))(x)
	x = Dropout(0.5)(x)
	# Before the last layer, save a layer with logits, which will help in calibration
	logits = Dense(num_classes, name='logits')(x)
	# The final fully-connected layer head will have a softmax dense layer.
	out = Activation('softmax')(logits)

	# Construct the CNN.
	model = Model(inputs, out)
	# Return the CNN.
	return model

# %% [markdown]
# ## **Define functions**

# %%
def fit_TemperatureCalibration(train_X_y, valid_X_y=None, epochs=100):
    ''' From: https://github.com/cerlymarco/MEDIUM_NoteBook/blob/master/NeuralNet_Calibration/NeuralNet_Calibration.ipynb; inspired by: https://github.com/stellargraph/stellargraph/blob/develop/stellargraph/calibration.py 
    Performs temperature scaling'''
    
    T = tf.Variable(tf.ones(shape=(1,)), name="T")
    history = []
    early_stopping = False
    optimizer = Adam(learning_rate=0.001)
    
    def cost(T, x, y):

        scaled_logits = tf.multiply(x=x, y=1.0 / T)

        cost_value = tf.reduce_mean(
            tf.nn.softmax_cross_entropy_with_logits(logits=scaled_logits, labels=y)
        )

        return cost_value

    def grad(T, x, y):

        with tf.GradientTape() as tape:
            cost_value = cost(T, x, y)

        return cost_value, tape.gradient(cost_value, T)
    
    
    X_train, y_train = train_X_y
    if valid_X_y:
        X_valid, y_valid = valid_X_y
        early_stopping = True
    
    
    for epoch in range(epochs):
        train_cost, grads = grad(T, X_train, y_train)
        optimizer.apply_gradients(zip([grads], [T]))
        if early_stopping:
            val_cost = cost(T, X_valid, y_valid)
            if (len(history) > 0) and (val_cost > history[-1][1]):
                break
            else: 
                history.append([train_cost, val_cost, T.numpy()[0]])
        else:
            history.append([train_cost, T.numpy()[0]])

    history = np.asarray(history)
    temperature = history[-1, -1]
    
    return temperature

def cal_softmax(x):
    """
    From: https://github.com/markus93/NN_calibration
    Compute softmax values for each sets of scores in x.
    
    Parameters:
        x (numpy.ndarray): array containing m samples with n-dimensions (m,n)
    Returns:
        x_softmax (numpy.ndarray) softmaxed values for initial (m,n) array
    """
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum(axis=1, keepdims=1)

def evaluate(probs, y_true, verbose = False, normalize = False):
    """
    Modified from: https://github.com/markus93/NN_calibration
    Evaluate model using Error Rate and loss
    
    Params:
        probs: a list containing probabilities for all the classes with a shape of (samples, classes)
        y_true: a list containing the actual class labels
        verbose: (bool) are the scores printed out. (default = False)
        normalize: (bool) in case of 1-vs-K calibration, the probabilities need to be normalized.
        
    Returns:
        (error, loss), returns various scoring measures
    """
    
    preds = np.argmax(probs, axis=1)  # Take maximum confidence as prediction
    
    if normalize:
        confs = np.max(probs, axis=1)/np.sum(probs, axis=1)
        # Check if everything below or equal to 1?
    else:
        confs = np.max(probs, axis=1)  # Take only maximum confidence
    
    accuracy = metrics.accuracy_score(y_true, preds) * 100
    error = 100 - accuracy
        
    loss = log_loss(y_true=y_true, y_pred=probs)
        
    if verbose:
        print("Accuracy:", accuracy)
        print("Error:", error)
        print("Loss:", loss)
    
    return (error, loss)

# %% [markdown]
# ## **Train the network with 10,000 simulations from each model**
# Use the simulated dataset to train the network, by splitting the data with 75% of simulations for training and 25% for validation.

# %%
# Load Numpy arrays containing simulations.
u1 = np.load("./trainingSims/simModel1.npy",mmap_mode='r')
u2 = np.load("./trainingSims/simModel2.npy",mmap_mode='r')
u3 = np.load("./trainingSims/simModel3.npy",mmap_mode='r')

# Combine all arrays.
x=np.concatenate((u1,u2,u3),axis=0)

# Label each simulated array.
y=[0 for i in range(len(u1))]
y.extend([1 for i in range(len(u2))])
y.extend([2 for i in range(len(u3))])
y = np.array(y)

#delete temporary files to free memory.
del (u1,u2,u3)

# Print label and simulations length, these should be the same.
print (len(x), len(y))

# Shuffle the arrays for training, keeping the labels in the same order.
shf = list(range(len(x)))
shuffle(shf)
y = y[shf]
x = x[shf]

# Convert the reference allele to -1.
x[x == 0] = -1

#Add missing data (coded as 0s) to the simulated matrices (with a percentage according to the empirical data - 15% in E. segueriana).
missD = int(x.shape[1]*x.shape[2]*.15)
for i in range(x.shape[0]):
  for m in range(missD):
    j = random.randint(0, x.shape[1] - 1)
    k = random.randint(0, x.shape[2] - 1)
    x[i][j][k] = 0
del(missD)

# Separate train (75%) and validate (25%) sets.
xtrain, xtest = x[int(len(y)*.25):], x[:int(len(y)*.25)]
ytrain, ytest = y[int(len(y)*.25):], y[:int(len(y)*.25)]
del(x)
ytest = keras.utils.to_categorical(ytest, num_classes)
ytrain = keras.utils.to_categorical(ytrain, num_classes)

# Create the CNN network.
model = create_cnn(xtest)

# Compile the CNN.
model.compile(loss=keras.losses.categorical_crossentropy,
	              optimizer='Adam',
	              metrics=['accuracy'])

# Check the architecture.
model.summary()

# Run the CNN with early stopping and reducing the learning rate after reaching a plateau. Save the model with the best val_accuracy.
earlyStopping = EarlyStopping(monitor='val_accuracy', patience=150, verbose=0, mode='max', restore_best_weights=True)

model.fit(xtrain, ytrain, batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(xtest, ytest),callbacks=[earlyStopping])

# Save the model.
model.save(filepath='Trained_uncalibrated_Esegueriana._MissingData.acc.mod')
# Out:
# 30000 30000
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 1000, 270)]       0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 999, 250)          135250
# _________________________________________________________________
# batch_normalization (BatchNo (None, 999, 250)          1000
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 997, 20)           15020
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 997, 20)           80
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 993, 20)           2020
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 993, 20)           80
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 974, 20)           8020
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 974, 20)           80
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 925, 20)           20020
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 925, 20)           80
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 924, 125)          5125
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 924, 125)          500
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 923, 125)          31375
# _________________________________________________________________
# average_pooling1d (AveragePo (None, 461, 125)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 57625)             0
# _________________________________________________________________
# dense (Dense)                (None, 125)               7203250
# _________________________________________________________________
# dropout (Dropout)            (None, 125)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 125)               15750
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 125)               0
# _________________________________________________________________
# logits (Dense)               (None, 3)                 378
# _________________________________________________________________
# activation (Activation)      (None, 3)                 0
# =================================================================
# Total params: 7,438,028
# Trainable params: 7,437,118
# Non-trainable params: 910
# _________________________________________________________________
#  Epoch 1/500
#  [==============================] - 623s 14s/step - loss: 2.0425 - accuracy: 0.6240 - val_loss: 1.5657 - val_accuracy: 0.3225
#  Epoch 2/500
#  [==============================] - 616s 14s/step - loss: 0.9120 - accuracy: 0.7647 - val_loss: 1.5644 - val_accuracy: 0.3225
#  Epoch 3/500
#  [==============================] - 612s 14s/step - loss: 0.7290 - accuracy: 0.8185 - val_loss: 2.1452 - val_accuracy: 0.3225
#  Epoch 4/500
#  [==============================] - 616s 14s/step - loss: 0.5691 - accuracy: 0.8791 - val_loss: 7.6817 - val_accuracy: 0.3365
#  Epoch 5/500
#  [==============================] - 612s 14s/step - loss: 0.4125 - accuracy: 0.9246 - val_loss: 12.5887 - val_accuracy: 0.3365
#  Epoch 6/500
#  [==============================] - 614s 14s/step - loss: 0.3206 - accuracy: 0.9464 - val_loss: 8.5633 - val_accuracy: 0.3364
#  Epoch 7/500
#  [==============================] - 604s 13s/step - loss: 0.2556 - accuracy: 0.9628 - val_loss: 29.2979 - val_accuracy: 0.3365
#  Epoch 8/500
#  [==============================] - 616s 14s/step - loss: 0.2270 - accuracy: 0.9656 - val_loss: 31.1173 - val_accuracy: 0.3396
#  Epoch 9/500
#  [==============================] - 612s 14s/step - loss: 0.1952 - accuracy: 0.9704 - val_loss: 8.0362 - val_accuracy: 0.5395
#  Epoch 10/500
#  [==============================] - 617s 14s/step - loss: 0.1637 - accuracy: 0.9797 - val_loss: 19.1264 - val_accuracy: 0.3225
#  Epoch 11/500
#  [==============================] - 615s 14s/step - loss: 0.1373 - accuracy: 0.9858 - val_loss: 20.2389 - val_accuracy: 0.3248
#  Epoch 12/500
#  [==============================] - 616s 14s/step - loss: 0.1360 - accuracy: 0.9846 - val_loss: 5.1016 - val_accuracy: 0.5145
#  Epoch 13/500
#  [==============================] - 616s 14s/step - loss: 0.1204 - accuracy: 0.9881 - val_loss: 21.7072 - val_accuracy: 0.4451
#  Epoch 14/500
#  [==============================] - 615s 14s/step - loss: 0.0981 - accuracy: 0.9937 - val_loss: 6.3742 - val_accuracy: 0.5895
#  Epoch 15/500
#  [==============================] - 616s 14s/step - loss: 0.0991 - accuracy: 0.9912 - val_loss: 8.8811 - val_accuracy: 0.5203
#  Epoch 16/500
#  [==============================] - 617s 14s/step - loss: 0.1014 - accuracy: 0.9901 - val_loss: 15.4108 - val_accuracy: 0.4012
#  Epoch 17/500
#  [==============================] - 614s 14s/step - loss: 0.0820 - accuracy: 0.9949 - val_loss: 8.4001 - val_accuracy: 0.4993
#  Epoch 18/500
#  [==============================] - 613s 14s/step - loss: 0.0749 - accuracy: 0.9948 - val_loss: 30.0038 - val_accuracy: 0.3389
#  Epoch 19/500
#  [==============================] - 613s 14s/step - loss: 0.0801 - accuracy: 0.9932 - val_loss: 16.1886 - val_accuracy: 0.3928
#  Epoch 20/500
#  [==============================] - 616s 14s/step - loss: 0.0760 - accuracy: 0.9931 - val_loss: 24.3578 - val_accuracy: 0.3765
#  Epoch 21/500
#  [==============================] - 613s 14s/step - loss: 0.0682 - accuracy: 0.9952 - val_loss: 1.8089 - val_accuracy: 0.8380
#  Epoch 22/500
#  [==============================] - 611s 14s/step - loss: 0.0598 - accuracy: 0.9969 - val_loss: 4.5967 - val_accuracy: 0.6073
#  Epoch 23/500
#  [==============================] - 613s 14s/step - loss: 0.0556 - accuracy: 0.9970 - val_loss: 8.8282 - val_accuracy: 0.4315
#  Epoch 24/500
#  [==============================] - 612s 14s/step - loss: 0.0521 - accuracy: 0.9971 - val_loss: 2.5117 - val_accuracy: 0.7509
#  Epoch 25/500
#  [==============================] - 613s 14s/step - loss: 0.0530 - accuracy: 0.9971 - val_loss: 3.9701 - val_accuracy: 0.6811
#  Epoch 26/500
#  [==============================] - 617s 14s/step - loss: 0.0527 - accuracy: 0.9963 - val_loss: 3.4126 - val_accuracy: 0.7256
#  Epoch 27/500
#  [==============================] - 615s 14s/step - loss: 0.0536 - accuracy: 0.9963 - val_loss: 5.1119 - val_accuracy: 0.6213
#  Epoch 28/500
#  [==============================] - 617s 14s/step - loss: 0.0537 - accuracy: 0.9964 - val_loss: 2.6163 - val_accuracy: 0.7905
#  Epoch 29/500
#  [==============================] - 614s 14s/step - loss: 0.0508 - accuracy: 0.9970 - val_loss: 2.5719 - val_accuracy: 0.7368
#  Epoch 30/500
#  [==============================] - 612s 14s/step - loss: 0.0475 - accuracy: 0.9970 - val_loss: 17.4462 - val_accuracy: 0.5861
#  Epoch 31/500
#  [==============================] - 613s 14s/step - loss: 0.0442 - accuracy: 0.9977 - val_loss: 12.1176 - val_accuracy: 0.6627
#  Epoch 32/500
#  [==============================] - 612s 14s/step - loss: 0.0419 - accuracy: 0.9981 - val_loss: 20.9592 - val_accuracy: 0.4827
#  Epoch 33/500
#  [==============================] - 612s 14s/step - loss: 0.0367 - accuracy: 0.9989 - val_loss: 0.6240 - val_accuracy: 0.9176
#  Epoch 34/500
#  [==============================] - 613s 14s/step - loss: 0.0385 - accuracy: 0.9984 - val_loss: 8.3522 - val_accuracy: 0.6447
#  Epoch 35/500
#  [==============================] - 615s 14s/step - loss: 0.0424 - accuracy: 0.9972 - val_loss: 31.4826 - val_accuracy: 0.4597
#  Epoch 36/500
#  [==============================] - 618s 14s/step - loss: 0.0471 - accuracy: 0.9961 - val_loss: 14.4693 - val_accuracy: 0.6396
#  Epoch 37/500
#  [==============================] - 617s 14s/step - loss: 0.0452 - accuracy: 0.9973 - val_loss: 12.4704 - val_accuracy: 0.5389
#  Epoch 38/500
#  [==============================] - 610s 14s/step - loss: 0.0423 - accuracy: 0.9971 - val_loss: 8.2815 - val_accuracy: 0.4831
#  Epoch 39/500
#  [==============================] - 616s 14s/step - loss: 0.0353 - accuracy: 0.9983 - val_loss: 46.4193 - val_accuracy: 0.3460
#  Epoch 40/500
#  [==============================] - 612s 14s/step - loss: 0.0428 - accuracy: 0.9960 - val_loss: 32.4541 - val_accuracy: 0.3456
#  Epoch 41/500
#  [==============================] - 615s 14s/step - loss: 0.0371 - accuracy: 0.9981 - val_loss: 1.3914 - val_accuracy: 0.8535
#  Epoch 42/500
#  [==============================] - 611s 14s/step - loss: 0.0447 - accuracy: 0.9963 - val_loss: 10.6549 - val_accuracy: 0.6268
#  Epoch 43/500
#  [==============================] - 616s 14s/step - loss: 0.0388 - accuracy: 0.9974 - val_loss: 2.5797 - val_accuracy: 0.7048
#  Epoch 44/500
#  [==============================] - 615s 14s/step - loss: 0.0409 - accuracy: 0.9965 - val_loss: 8.7441 - val_accuracy: 0.6603
#  Epoch 45/500
#  [==============================] - 614s 14s/step - loss: 0.0348 - accuracy: 0.9976 - val_loss: 15.2869 - val_accuracy: 0.4809
#  Epoch 46/500
#  [==============================] - 614s 14s/step - loss: 0.0307 - accuracy: 0.9984 - val_loss: 12.6286 - val_accuracy: 0.4967
#  Epoch 47/500
#  [==============================] - 616s 14s/step - loss: 0.0302 - accuracy: 0.9984 - val_loss: 27.7817 - val_accuracy: 0.5673
#  Epoch 48/500
#  [==============================] - 615s 14s/step - loss: 0.0344 - accuracy: 0.9985 - val_loss: 9.4588 - val_accuracy: 0.5707
#  Epoch 49/500
#  [==============================] - 613s 14s/step - loss: 0.0322 - accuracy: 0.9985 - val_loss: 0.8856 - val_accuracy: 0.8912
#  Epoch 50/500
#  [==============================] - 616s 14s/step - loss: 0.0339 - accuracy: 0.9972 - val_loss: 7.0381 - val_accuracy: 0.6681
#  Epoch 51/500
#  [==============================] - 617s 14s/step - loss: 0.0309 - accuracy: 0.9980 - val_loss: 2.2259 - val_accuracy: 0.8663
#  Epoch 52/500
#  [==============================] - 618s 14s/step - loss: 0.0251 - accuracy: 0.9992 - val_loss: 0.2173 - val_accuracy: 0.9705
#  Epoch 53/500
#  [==============================] - 613s 14s/step - loss: 0.0258 - accuracy: 0.9984 - val_loss: 6.9504 - val_accuracy: 0.6640
#  Epoch 54/500
#  [==============================] - 615s 14s/step - loss: 0.0336 - accuracy: 0.9968 - val_loss: 0.4866 - val_accuracy: 0.9308
#  Epoch 55/500
#  [==============================] - 613s 14s/step - loss: 0.0404 - accuracy: 0.9969 - val_loss: 5.9050 - val_accuracy: 0.6564
#  Epoch 56/500
#  [==============================] - 611s 14s/step - loss: 0.0308 - accuracy: 0.9978 - val_loss: 10.9345 - val_accuracy: 0.6600
#  Epoch 57/500
#  [==============================] - 613s 14s/step - loss: 0.0349 - accuracy: 0.9965 - val_loss: 3.4363 - val_accuracy: 0.6971
#  Epoch 58/500
#  [==============================] - 616s 14s/step - loss: 0.0307 - accuracy: 0.9980 - val_loss: 0.4318 - val_accuracy: 0.9543
#  Epoch 59/500
#  [==============================] - 613s 14s/step - loss: 0.0363 - accuracy: 0.9962 - val_loss: 7.0590 - val_accuracy: 0.6608
#  Epoch 60/500
#  [==============================] - 612s 14s/step - loss: 0.0318 - accuracy: 0.9979 - val_loss: 0.4970 - val_accuracy: 0.9421
#  Epoch 61/500
#  [==============================] - 616s 14s/step - loss: 0.0280 - accuracy: 0.9984 - val_loss: 9.9288 - val_accuracy: 0.6025
#  Epoch 62/500
#  [==============================] - 612s 14s/step - loss: 0.0331 - accuracy: 0.9967 - val_loss: 24.2225 - val_accuracy: 0.6404
#  Epoch 63/500
#  [==============================] - 614s 14s/step - loss: 0.0332 - accuracy: 0.9966 - val_loss: 11.4952 - val_accuracy: 0.6529
#  Epoch 64/500
#  [==============================] - 615s 14s/step - loss: 0.0266 - accuracy: 0.9983 - val_loss: 0.3288 - val_accuracy: 0.9559
#  Epoch 65/500
#  [==============================] - 611s 14s/step - loss: 0.0269 - accuracy: 0.9979 - val_loss: 29.8450 - val_accuracy: 0.3409
#  Epoch 66/500
#  [==============================] - 612s 14s/step - loss: 0.0247 - accuracy: 0.9984 - val_loss: 6.9125 - val_accuracy: 0.6547
#  Epoch 67/500
#  [==============================] - 611s 14s/step - loss: 0.0190 - accuracy: 0.9993 - val_loss: 5.8698 - val_accuracy: 0.6401
#  Epoch 68/500
#  [==============================] - 613s 14s/step - loss: 0.0174 - accuracy: 0.9995 - val_loss: 0.4297 - val_accuracy: 0.9435
#  Epoch 69/500
#  [==============================] - 616s 14s/step - loss: 0.0173 - accuracy: 0.9990 - val_loss: 11.4873 - val_accuracy: 0.5500
#  Epoch 70/500
#  [==============================] - 613s 14s/step - loss: 0.0352 - accuracy: 0.9955 - val_loss: 20.8165 - val_accuracy: 0.5427
#  Epoch 71/500
#  [==============================] - 614s 14s/step - loss: 0.0253 - accuracy: 0.9984 - val_loss: 1.2230 - val_accuracy: 0.8625
#  Epoch 72/500
#  [==============================] - 610s 14s/step - loss: 0.0197 - accuracy: 0.9993 - val_loss: 28.9952 - val_accuracy: 0.3409
#  Epoch 73/500
#  [==============================] - 603s 13s/step - loss: 0.0205 - accuracy: 0.9985 - val_loss: 0.3133 - val_accuracy: 0.9580
#  Epoch 74/500
#  [==============================] - 612s 14s/step - loss: 0.0244 - accuracy: 0.9976 - val_loss: 6.3103 - val_accuracy: 0.6321
#  Epoch 75/500
#  [==============================] - 615s 14s/step - loss: 0.0193 - accuracy: 0.9987 - val_loss: 9.6529 - val_accuracy: 0.5216
#  Epoch 76/500
#  [==============================] - 612s 14s/step - loss: 0.0151 - accuracy: 0.9994 - val_loss: 3.8947 - val_accuracy: 0.7387
#  Epoch 77/500
#  [==============================] - 611s 14s/step - loss: 0.0186 - accuracy: 0.9988 - val_loss: 7.5437 - val_accuracy: 0.6535
#  Epoch 78/500
#  [==============================] - 612s 14s/step - loss: 0.0268 - accuracy: 0.9975 - val_loss: 7.6141 - val_accuracy: 0.6499
#  Epoch 79/500
#  [==============================] - 615s 14s/step - loss: 0.0436 - accuracy: 0.9970 - val_loss: 0.4551 - val_accuracy: 0.9313
#  Epoch 80/500
#  [==============================] - 614s 14s/step - loss: 0.0326 - accuracy: 0.9978 - val_loss: 4.8411 - val_accuracy: 0.6389
#  Epoch 81/500
#  [==============================] - 611s 14s/step - loss: 0.0217 - accuracy: 0.9990 - val_loss: 3.7748 - val_accuracy: 0.7408
#  Epoch 82/500
#  [==============================] - 614s 14s/step - loss: 0.0219 - accuracy: 0.9979 - val_loss: 2.3390 - val_accuracy: 0.8327
#  Epoch 83/500
#  [==============================] - 610s 14s/step - loss: 0.0180 - accuracy: 0.9991 - val_loss: 4.1601 - val_accuracy: 0.7435
#  Epoch 84/500
#  [==============================] - 614s 14s/step - loss: 0.0121 - accuracy: 0.9998 - val_loss: 3.4514 - val_accuracy: 0.7405
#  Epoch 85/500
#  [==============================] - 615s 14s/step - loss: 0.0137 - accuracy: 0.9993 - val_loss: 1.9305 - val_accuracy: 0.8139
#  Epoch 86/500
#  [==============================] - 614s 14s/step - loss: 0.0125 - accuracy: 0.9996 - val_loss: 16.6868 - val_accuracy: 0.6375
#  Epoch 87/500
#  [==============================] - 606s 13s/step - loss: 0.0177 - accuracy: 0.9985 - val_loss: 3.8909 - val_accuracy: 0.7208
#  Epoch 88/500
#  [==============================] - 613s 14s/step - loss: 0.0133 - accuracy: 0.9995 - val_loss: 0.5687 - val_accuracy: 0.9399
#  Epoch 89/500
#  [==============================] - 618s 14s/step - loss: 0.0172 - accuracy: 0.9980 - val_loss: 1.6111 - val_accuracy: 0.8117
#  Epoch 90/500
#  [==============================] - 617s 14s/step - loss: 0.0206 - accuracy: 0.9979 - val_loss: 3.9453 - val_accuracy: 0.6732
#  Epoch 91/500
#  [==============================] - 613s 14s/step - loss: 0.0188 - accuracy: 0.9987 - val_loss: 7.2743 - val_accuracy: 0.6596
#  Epoch 92/500
#  [==============================] - 610s 14s/step - loss: 0.0238 - accuracy: 0.9971 - val_loss: 110.9711 - val_accuracy: 0.3368
#  Epoch 93/500
#  [==============================] - 614s 14s/step - loss: 0.0196 - accuracy: 0.9986 - val_loss: 8.3225 - val_accuracy: 0.6072
#  Epoch 94/500
#  [==============================] - 614s 14s/step - loss: 0.0158 - accuracy: 0.9988 - val_loss: 11.8318 - val_accuracy: 0.5103
#  Epoch 95/500
#  [==============================] - 608s 14s/step - loss: 0.0155 - accuracy: 0.9989 - val_loss: 6.2617 - val_accuracy: 0.7336
#  Epoch 96/500
#  [==============================] - 611s 14s/step - loss: 0.0135 - accuracy: 0.9990 - val_loss: 7.1853 - val_accuracy: 0.6569
#  Epoch 97/500
#  [==============================] - 617s 14s/step - loss: 0.0162 - accuracy: 0.9983 - val_loss: 1.1476 - val_accuracy: 0.8641
#  Epoch 98/500
#  [==============================] - 616s 14s/step - loss: 0.0197 - accuracy: 0.9978 - val_loss: 21.8971 - val_accuracy: 0.3439
#  Epoch 99/500
#  [==============================] - 613s 14s/step - loss: 0.0191 - accuracy: 0.9987 - val_loss: 0.1894 - val_accuracy: 0.9649
#  Epoch 100/500
#  [==============================] - 609s 14s/step - loss: 0.0192 - accuracy: 0.9983 - val_loss: 3.1363 - val_accuracy: 0.7261
#  Epoch 101/500
#  [==============================] - 607s 14s/step - loss: 0.0208 - accuracy: 0.9988 - val_loss: 1.4845 - val_accuracy: 0.8513
#  Epoch 102/500
#  [==============================] - 610s 14s/step - loss: 0.0146 - accuracy: 0.9994 - val_loss: 10.7322 - val_accuracy: 0.6736
#  Epoch 103/500
#  [==============================] - 611s 14s/step - loss: 0.0162 - accuracy: 0.9984 - val_loss: 1.5620 - val_accuracy: 0.8439
#  Epoch 104/500
#  [==============================] - 612s 14s/step - loss: 0.0212 - accuracy: 0.9976 - val_loss: 7.0462 - val_accuracy: 0.6281
#  Epoch 105/500
#  [==============================] - 612s 14s/step - loss: 0.0249 - accuracy: 0.9975 - val_loss: 0.9541 - val_accuracy: 0.9153
#  Epoch 106/500
#  [==============================] - 616s 14s/step - loss: 0.0163 - accuracy: 0.9992 - val_loss: 20.3535 - val_accuracy: 0.6137
#  Epoch 107/500
#  [==============================] - 615s 14s/step - loss: 0.0165 - accuracy: 0.9991 - val_loss: 4.4067 - val_accuracy: 0.7192
#  Epoch 108/500
#  [==============================] - 613s 14s/step - loss: 0.0117 - accuracy: 0.9996 - val_loss: 11.7499 - val_accuracy: 0.6539
#  Epoch 109/500
#  [==============================] - 612s 14s/step - loss: 0.0124 - accuracy: 0.9995 - val_loss: 10.6412 - val_accuracy: 0.6665
#  Epoch 110/500
#  [==============================] - 605s 13s/step - loss: 0.0094 - accuracy: 0.9997 - val_loss: 17.7808 - val_accuracy: 0.6688
#  Epoch 111/500
#  [==============================] - 614s 14s/step - loss: 0.0118 - accuracy: 0.9990 - val_loss: 3.1042 - val_accuracy: 0.7665
#  Epoch 112/500
#  [==============================] - 615s 14s/step - loss: 0.0154 - accuracy: 0.9982 - val_loss: 9.5387 - val_accuracy: 0.6625
#  Epoch 113/500
#  [==============================] - 616s 14s/step - loss: 0.0246 - accuracy: 0.9973 - val_loss: 39.4560 - val_accuracy: 0.3409
#  Epoch 114/500
#  [==============================] - 612s 14s/step - loss: 0.0163 - accuracy: 0.9992 - val_loss: 0.7861 - val_accuracy: 0.9091
#  Epoch 115/500
#  [==============================] - 607s 13s/step - loss: 0.0174 - accuracy: 0.9988 - val_loss: 4.8959 - val_accuracy: 0.7000
#  Epoch 116/500
#  [==============================] - 609s 14s/step - loss: 0.0125 - accuracy: 0.9991 - val_loss: 4.9322 - val_accuracy: 0.6849
#  Epoch 117/500
#  [==============================] - 609s 14s/step - loss: 0.0206 - accuracy: 0.9981 - val_loss: 7.4620 - val_accuracy: 0.6752
#  Epoch 118/500
#  [==============================] - 615s 14s/step - loss: 0.0287 - accuracy: 0.9989 - val_loss: 18.9979 - val_accuracy: 0.4900
#  Epoch 119/500
#  [==============================] - 613s 14s/step - loss: 0.0295 - accuracy: 0.9970 - val_loss: 4.9056 - val_accuracy: 0.6867
#  Epoch 120/500
#  [==============================] - 613s 14s/step - loss: 0.0198 - accuracy: 0.9989 - val_loss: 7.5860 - val_accuracy: 0.6393
#  Epoch 121/500
#  [==============================] - 614s 14s/step - loss: 0.0152 - accuracy: 0.9993 - val_loss: 5.9237 - val_accuracy: 0.5819
#  Epoch 122/500
#  [==============================] - 608s 14s/step - loss: 0.0158 - accuracy: 0.9986 - val_loss: 20.3493 - val_accuracy: 0.6211
#  Epoch 123/500
#  [==============================] - 609s 14s/step - loss: 0.0178 - accuracy: 0.9990 - val_loss: 1.5681 - val_accuracy: 0.8579
#  Epoch 124/500
#  [==============================] - 607s 14s/step - loss: 0.0210 - accuracy: 0.9983 - val_loss: 4.6759 - val_accuracy: 0.6435
#  Epoch 125/500
#  [==============================] - 592s 13s/step - loss: 0.0123 - accuracy: 0.9996 - val_loss: 8.4703 - val_accuracy: 0.5821
#  Epoch 126/500
#  [==============================] - 604s 13s/step - loss: 0.0124 - accuracy: 0.9992 - val_loss: 0.9299 - val_accuracy: 0.8824
#  Epoch 127/500
#  [==============================] - 610s 14s/step - loss: 0.0166 - accuracy: 0.9984 - val_loss: 3.3657 - val_accuracy: 0.7984
#  Epoch 128/500
#  [==============================] - 615s 14s/step - loss: 0.0115 - accuracy: 0.9996 - val_loss: 9.9008 - val_accuracy: 0.6543
#  Epoch 129/500
#  [==============================] - 615s 14s/step - loss: 0.0083 - accuracy: 0.9999 - val_loss: 0.5754 - val_accuracy: 0.9399
#  Epoch 130/500
#  [==============================] - 614s 14s/step - loss: 0.0078 - accuracy: 0.9999 - val_loss: 0.3585 - val_accuracy: 0.9593
#  Epoch 131/500
#  [==============================] - 607s 14s/step - loss: 0.0082 - accuracy: 0.9995 - val_loss: 1.9147 - val_accuracy: 0.8239
#  Epoch 132/500
#  [==============================] - 610s 14s/step - loss: 0.0143 - accuracy: 0.9983 - val_loss: 11.7525 - val_accuracy: 0.6611
#  Epoch 133/500
#  [==============================] - 631s 14s/step - loss: 0.0154 - accuracy: 0.9987 - val_loss: 4.9701 - val_accuracy: 0.7031
#  Epoch 134/500
#  [==============================] - 610s 14s/step - loss: 0.0150 - accuracy: 0.9987 - val_loss: 38.0945 - val_accuracy: 0.5201
#  Epoch 135/500
#  [==============================] - 613s 14s/step - loss: 0.0229 - accuracy: 0.9972 - val_loss: 26.1262 - val_accuracy: 0.4815
#  Epoch 136/500
#  [==============================] - 618s 14s/step - loss: 0.0167 - accuracy: 0.9990 - val_loss: 3.4626 - val_accuracy: 0.7225
#  Epoch 137/500
#  [==============================] - 614s 14s/step - loss: 0.0121 - accuracy: 0.9993 - val_loss: 17.9322 - val_accuracy: 0.6529
#  Epoch 138/500
#  [==============================] - 619s 14s/step - loss: 0.0120 - accuracy: 0.9993 - val_loss: 1.4899 - val_accuracy: 0.8747
#  Epoch 139/500
#  [==============================] - 614s 14s/step - loss: 0.0121 - accuracy: 0.9993 - val_loss: 11.7081 - val_accuracy: 0.6460
#  Epoch 140/500
#  [==============================] - 613s 14s/step - loss: 0.0175 - accuracy: 0.9980 - val_loss: 2.0741 - val_accuracy: 0.8303
#  Epoch 141/500
#  [==============================] - 611s 14s/step - loss: 0.0144 - accuracy: 0.9990 - val_loss: 1.7820 - val_accuracy: 0.8664
#  Epoch 142/500
#  [==============================] - 611s 14s/step - loss: 0.0344 - accuracy: 0.9949 - val_loss: 2.3188 - val_accuracy: 0.7479
#  Epoch 143/500
#  [==============================] - 611s 14s/step - loss: 0.0269 - accuracy: 0.9981 - val_loss: 7.7329 - val_accuracy: 0.6667
#  Epoch 144/500
#  [==============================] - 614s 14s/step - loss: 0.0261 - accuracy: 0.9989 - val_loss: 3.1698 - val_accuracy: 0.8021
#  Epoch 145/500
#  [==============================] - 616s 14s/step - loss: 0.0147 - accuracy: 0.9997 - val_loss: 1.4853 - val_accuracy: 0.8748
#  Epoch 146/500
#  [==============================] - 613s 14s/step - loss: 0.0212 - accuracy: 0.9983 - val_loss: 0.8849 - val_accuracy: 0.8753
#  Epoch 147/500
#  [==============================] - 611s 14s/step - loss: 0.0239 - accuracy: 0.9989 - val_loss: 10.9412 - val_accuracy: 0.6633
#  Epoch 148/500
#  [==============================] - 617s 14s/step - loss: 0.0178 - accuracy: 0.9991 - val_loss: 5.2277 - val_accuracy: 0.6644
#  Epoch 149/500
#  [==============================] - 615s 14s/step - loss: 0.0223 - accuracy: 0.9986 - val_loss: 10.1114 - val_accuracy: 0.6625
#  Epoch 150/500
#  [==============================] - 616s 14s/step - loss: 0.0178 - accuracy: 0.9991 - val_loss: 4.2138 - val_accuracy: 0.6691
#  Epoch 151/500
#  [==============================] - 611s 14s/step - loss: 0.0141 - accuracy: 0.9988 - val_loss: 13.9306 - val_accuracy: 0.6495
#  Epoch 152/500
#  [==============================] - 613s 14s/step - loss: 0.0117 - accuracy: 0.9994 - val_loss: 0.1676 - val_accuracy: 0.9728
#  Epoch 153/500
#  [==============================] - 612s 14s/step - loss: 0.0101 - accuracy: 0.9996 - val_loss: 20.3338 - val_accuracy: 0.3461
#  Epoch 154/500
#  [==============================] - 612s 14s/step - loss: 0.0087 - accuracy: 0.9996 - val_loss: 4.3358 - val_accuracy: 0.7372
#  Epoch 155/500
#  [==============================] - 611s 14s/step - loss: 0.0135 - accuracy: 0.9987 - val_loss: 5.1022 - val_accuracy: 0.7028
#  Epoch 156/500
#  [==============================] - 613s 14s/step - loss: 0.0181 - accuracy: 0.9985 - val_loss: 5.1355 - val_accuracy: 0.7085
#  Epoch 157/500
#  [==============================] - 603s 13s/step - loss: 0.0148 - accuracy: 0.9994 - val_loss: 0.4487 - val_accuracy: 0.9477
#  Epoch 158/500
#  [==============================] - 553s 12s/step - loss: 0.0112 - accuracy: 0.9994 - val_loss: 8.2217 - val_accuracy: 0.5893
#  Epoch 159/500
#  [==============================] - 548s 12s/step - loss: 0.0090 - accuracy: 0.9996 - val_loss: 1.3122 - val_accuracy: 0.8813
#  Epoch 160/500
#  [==============================] - 552s 12s/step - loss: 0.0126 - accuracy: 0.9989 - val_loss: 5.9804 - val_accuracy: 0.6731
#  Epoch 161/500
#  [==============================] - 562s 13s/step - loss: 0.0214 - accuracy: 0.9976 - val_loss: 27.9070 - val_accuracy: 0.5885
#  Epoch 162/500
#  [==============================] - 552s 12s/step - loss: 0.0112 - accuracy: 0.9999 - val_loss: 9.3155 - val_accuracy: 0.6548
#  Epoch 163/500
#  [==============================] - 548s 12s/step - loss: 0.0076 - accuracy: 0.9999 - val_loss: 2.8869 - val_accuracy: 0.7841
#  Epoch 164/500
#  [==============================] - 548s 12s/step - loss: 0.0113 - accuracy: 0.9992 - val_loss: 0.4274 - val_accuracy: 0.9519
#  Epoch 165/500
#  [==============================] - 554s 12s/step - loss: 0.0126 - accuracy: 0.9992 - val_loss: 11.7190 - val_accuracy: 0.6564
#  Epoch 166/500
#  [==============================] - 552s 12s/step - loss: 0.0121 - accuracy: 0.9987 - val_loss: 21.8583 - val_accuracy: 0.6365
#  Epoch 167/500
#  [==============================] - 552s 12s/step - loss: 0.0197 - accuracy: 0.9975 - val_loss: 12.4456 - val_accuracy: 0.6515
#  Epoch 168/500
#  [==============================] - 551s 12s/step - loss: 0.0263 - accuracy: 0.9974 - val_loss: 1.1422 - val_accuracy: 0.8944
#  Epoch 169/500
#  [==============================] - 552s 12s/step - loss: 0.0196 - accuracy: 0.9987 - val_loss: 22.9160 - val_accuracy: 0.5480
#  Epoch 170/500
#  [==============================] - 546s 12s/step - loss: 0.0164 - accuracy: 0.9984 - val_loss: 17.8416 - val_accuracy: 0.6565
#  Epoch 171/500
#  [==============================] - 551s 12s/step - loss: 0.0122 - accuracy: 0.9994 - val_loss: 0.2530 - val_accuracy: 0.9613
#  Epoch 172/500
#  [==============================] - 551s 12s/step - loss: 0.0099 - accuracy: 0.9996 - val_loss: 12.7526 - val_accuracy: 0.6567
#  Epoch 173/500
#  [==============================] - 548s 12s/step - loss: 0.0082 - accuracy: 0.9996 - val_loss: 1.1282 - val_accuracy: 0.8848
#  Epoch 174/500
#  [==============================] - 552s 12s/step - loss: 0.0071 - accuracy: 0.9996 - val_loss: 1.1707 - val_accuracy: 0.8712
#  Epoch 175/500
#  [==============================] - 552s 12s/step - loss: 0.0114 - accuracy: 0.9989 - val_loss: 1.6059 - val_accuracy: 0.8117
#  Epoch 176/500
#  [==============================] - 555s 12s/step - loss: 0.0139 - accuracy: 0.9985 - val_loss: 13.7226 - val_accuracy: 0.5835
#  Epoch 177/500
#  [==============================] - 550s 12s/step - loss: 0.0148 - accuracy: 0.9988 - val_loss: 1.1817 - val_accuracy: 0.8865
#  Epoch 178/500
#  [==============================] - 550s 12s/step - loss: 0.0114 - accuracy: 0.9995 - val_loss: 1.7601 - val_accuracy: 0.8539
#  Epoch 179/500
#  [==============================] - 552s 12s/step - loss: 0.0080 - accuracy: 0.9998 - val_loss: 2.8825 - val_accuracy: 0.7737
#  Epoch 180/500
#  [==============================] - 550s 12s/step - loss: 0.0073 - accuracy: 0.9997 - val_loss: 0.6671 - val_accuracy: 0.9080
#  Epoch 181/500
#  [==============================] - 550s 12s/step - loss: 0.0063 - accuracy: 0.9998 - val_loss: 11.5760 - val_accuracy: 0.6535
#  Epoch 182/500
#  [==============================] - 548s 12s/step - loss: 0.0075 - accuracy: 0.9996 - val_loss: 9.0171 - val_accuracy: 0.6663
#  Epoch 183/500
#  [==============================] - 551s 12s/step - loss: 0.0063 - accuracy: 0.9998 - val_loss: 12.7980 - val_accuracy: 0.6628
#  Epoch 184/500
#  [==============================] - 551s 12s/step - loss: 0.0069 - accuracy: 0.9996 - val_loss: 4.6402 - val_accuracy: 0.7161
#  Epoch 185/500
#  [==============================] - 551s 12s/step - loss: 0.0146 - accuracy: 0.9983 - val_loss: 14.6794 - val_accuracy: 0.6611
#  Epoch 186/500
#  [==============================] - 550s 12s/step - loss: 0.0160 - accuracy: 0.9982 - val_loss: 37.9724 - val_accuracy: 0.4551
#  Epoch 187/500
#  [==============================] - 548s 12s/step - loss: 0.0180 - accuracy: 0.9983 - val_loss: 5.5360 - val_accuracy: 0.7197
#  Epoch 188/500
#  [==============================] - 549s 12s/step - loss: 0.0225 - accuracy: 0.9983 - val_loss: 66.6445 - val_accuracy: 0.5679
#  Epoch 189/500
#  [==============================] - 549s 12s/step - loss: 0.0295 - accuracy: 0.9978 - val_loss: 11.1071 - val_accuracy: 0.5469
#  Epoch 190/500
#  [==============================] - 548s 12s/step - loss: 0.0261 - accuracy: 0.9981 - val_loss: 21.1589 - val_accuracy: 0.4928
#  Epoch 191/500
#  [==============================] - 552s 12s/step - loss: 0.0246 - accuracy: 0.9993 - val_loss: 0.9822 - val_accuracy: 0.9127
#  Epoch 192/500
#  [==============================] - 552s 12s/step - loss: 0.0219 - accuracy: 0.9977 - val_loss: 17.7039 - val_accuracy: 0.6148
#  Epoch 193/500
#  [==============================] - 502s 11s/step - loss: 0.0178 - accuracy: 0.9989 - val_loss: 8.1643 - val_accuracy: 0.6651
#  Epoch 194/500
#  [==============================] - 460s 10s/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 11.4811 - val_accuracy: 0.6559
#  Epoch 195/500
#  [==============================] - 460s 10s/step - loss: 0.0077 - accuracy: 0.9998 - val_loss: 6.2246 - val_accuracy: 0.6788
#  Epoch 196/500
#  [==============================] - 460s 10s/step - loss: 0.0083 - accuracy: 0.9997 - val_loss: 0.2374 - val_accuracy: 0.9683
#  Epoch 197/500
#  [==============================] - 461s 10s/step - loss: 0.0085 - accuracy: 0.9999 - val_loss: 12.3882 - val_accuracy: 0.6597
#  Epoch 198/500
#  [==============================] - 460s 10s/step - loss: 0.0069 - accuracy: 0.9996 - val_loss: 22.0026 - val_accuracy: 0.4128
#  Epoch 199/500
#  [==============================] - 460s 10s/step - loss: 0.0124 - accuracy: 0.9986 - val_loss: 4.7826 - val_accuracy: 0.6752
#  Epoch 200/500
#  [==============================] - 461s 10s/step - loss: 0.0329 - accuracy: 0.9976 - val_loss: 27.4628 - val_accuracy: 0.5809
#  Epoch 201/500
#  [==============================] - 462s 10s/step - loss: 0.0238 - accuracy: 0.9991 - val_loss: 0.2446 - val_accuracy: 0.9665
#  Epoch 202/500
#  [==============================] - 460s 10s/step - loss: 0.0170 - accuracy: 0.9992 - val_loss: 31.0923 - val_accuracy: 0.3439
#  Epoch 203/500
#  [==============================] - 457s 10s/step - loss: 0.0110 - accuracy: 0.9996 - val_loss: 0.3436 - val_accuracy: 0.9548
#  Epoch 204/500
#  [==============================] - 461s 10s/step - loss: 0.0085 - accuracy: 0.9998 - val_loss: 0.2062 - val_accuracy: 0.9705
#  Epoch 205/500
#  [==============================] - 460s 10s/step - loss: 0.0059 - accuracy: 0.9999 - val_loss: 0.8080 - val_accuracy: 0.9095
#  Epoch 206/500
#  [==============================] - 460s 10s/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.1323 - val_accuracy: 0.9813
#  Epoch 207/500
#  [==============================] - 460s 10s/step - loss: 0.0059 - accuracy: 0.9995 - val_loss: 5.9515 - val_accuracy: 0.6837
#  Epoch 208/500
#  [==============================] - 461s 10s/step - loss: 0.0152 - accuracy: 0.9987 - val_loss: 2.0591 - val_accuracy: 0.8661
#  Epoch 209/500
#  [==============================] - 461s 10s/step - loss: 0.0150 - accuracy: 0.9993 - val_loss: 0.3359 - val_accuracy: 0.9640
#  Epoch 210/500
#  [==============================] - 461s 10s/step - loss: 0.0108 - accuracy: 0.9994 - val_loss: 3.2330 - val_accuracy: 0.7917
#  Epoch 211/500
#  [==============================] - 461s 10s/step - loss: 0.0137 - accuracy: 0.9989 - val_loss: 0.2590 - val_accuracy: 0.9611
#  Epoch 212/500
#  [==============================] - 460s 10s/step - loss: 0.0183 - accuracy: 0.9976 - val_loss: 33.7537 - val_accuracy: 0.3529
#  Epoch 213/500
#  [==============================] - 460s 10s/step - loss: 0.0206 - accuracy: 0.9986 - val_loss: 15.2678 - val_accuracy: 0.4576
#  Epoch 214/500
#  [==============================] - 460s 10s/step - loss: 0.0186 - accuracy: 0.9985 - val_loss: 1.9310 - val_accuracy: 0.8584
#  Epoch 215/500
#  [==============================] - 462s 10s/step - loss: 0.0190 - accuracy: 0.9982 - val_loss: 22.6339 - val_accuracy: 0.6376
#  Epoch 216/500
#  [==============================] - 461s 10s/step - loss: 0.0135 - accuracy: 0.9996 - val_loss: 6.8592 - val_accuracy: 0.6717
#  Epoch 217/500
#  [==============================] - 462s 10s/step - loss: 0.0105 - accuracy: 0.9994 - val_loss: 5.6198 - val_accuracy: 0.6785
#  Epoch 218/500
#  [==============================] - 460s 10s/step - loss: 0.0079 - accuracy: 0.9998 - val_loss: 0.5302 - val_accuracy: 0.9404
#  Epoch 219/500
#  [==============================] - 460s 10s/step - loss: 0.0072 - accuracy: 0.9996 - val_loss: 1.1243 - val_accuracy: 0.8659
#  Epoch 220/500
#  [==============================] - 442s 10s/step - loss: 0.0092 - accuracy: 0.9994 - val_loss: 7.0640 - val_accuracy: 0.6588
#  Epoch 221/500
#  [==============================] - 424s 9s/step - loss: 0.0095 - accuracy: 0.9994 - val_loss: 9.9893 - val_accuracy: 0.6693
#  Epoch 222/500
#  [==============================] - 424s 9s/step - loss: 0.0089 - accuracy: 0.9996 - val_loss: 23.0695 - val_accuracy: 0.3999
#  Epoch 223/500
#  [==============================] - 427s 10s/step - loss: 0.0090 - accuracy: 0.9994 - val_loss: 5.2099 - val_accuracy: 0.7425
#  Epoch 224/500
#  [==============================] - 433s 10s/step - loss: 0.0149 - accuracy: 0.9986 - val_loss: 3.5754 - val_accuracy: 0.7628
#  Epoch 225/500
#  [==============================] - 423s 9s/step - loss: 0.0144 - accuracy: 0.9988 - val_loss: 3.4013 - val_accuracy: 0.8069
#  Epoch 226/500
#  [==============================] - 421s 9s/step - loss: 0.0113 - accuracy: 0.9997 - val_loss: 7.5752 - val_accuracy: 0.6649
#  Epoch 227/500
#  [==============================] - 418s 9s/step - loss: 0.0089 - accuracy: 0.9997 - val_loss: 4.5833 - val_accuracy: 0.7479
#  Epoch 228/500
#  [==============================] - 423s 9s/step - loss: 0.0067 - accuracy: 0.9998 - val_loss: 0.5481 - val_accuracy: 0.9457
#  Epoch 229/500
#  [==============================] - 421s 9s/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 4.5823 - val_accuracy: 0.7223
#  Epoch 230/500
#  [==============================] - 424s 9s/step - loss: 0.0041 - accuracy: 0.9999 - val_loss: 0.3792 - val_accuracy: 0.9541
#  Epoch 231/500
#  [==============================] - 421s 9s/step - loss: 0.0118 - accuracy: 0.9981 - val_loss: 16.8399 - val_accuracy: 0.6372
#  Epoch 232/500
#  [==============================] - 421s 9s/step - loss: 0.0141 - accuracy: 0.9989 - val_loss: 5.8319 - val_accuracy: 0.6613
#  Epoch 233/500
#  [==============================] - 431s 10s/step - loss: 0.0161 - accuracy: 0.9989 - val_loss: 28.6177 - val_accuracy: 0.6419
#  Epoch 234/500
#  [==============================] - 427s 10s/step - loss: 0.0142 - accuracy: 0.9992 - val_loss: 5.3527 - val_accuracy: 0.6608
#  Epoch 235/500
#  [==============================] - 420s 9s/step - loss: 0.0148 - accuracy: 0.9988 - val_loss: 0.4837 - val_accuracy: 0.9553
#  Epoch 236/500
#  [==============================] - 418s 9s/step - loss: 0.0158 - accuracy: 0.9988 - val_loss: 20.4027 - val_accuracy: 0.6413
#  Epoch 237/500
#  [==============================] - 423s 9s/step - loss: 0.0152 - accuracy: 0.9991 - val_loss: 1.7532 - val_accuracy: 0.8116
#  Epoch 238/500
#  [==============================] - 426s 9s/step - loss: 0.0126 - accuracy: 0.9994 - val_loss: 4.1596 - val_accuracy: 0.7397
#  Epoch 239/500
#  [==============================] - 421s 9s/step - loss: 0.0088 - accuracy: 0.9997 - val_loss: 0.1577 - val_accuracy: 0.9804
#  Epoch 240/500
#  [==============================] - 419s 9s/step - loss: 0.0083 - accuracy: 0.9996 - val_loss: 3.6613 - val_accuracy: 0.7495
#  Epoch 241/500
#  [==============================] - 418s 9s/step - loss: 0.0104 - accuracy: 0.9992 - val_loss: 17.6978 - val_accuracy: 0.5208
#  Epoch 242/500
#  [==============================] - 418s 9s/step - loss: 0.0107 - accuracy: 0.9993 - val_loss: 0.7232 - val_accuracy: 0.9208
#  Epoch 243/500
#  [==============================] - 423s 9s/step - loss: 0.0185 - accuracy: 0.9988 - val_loss: 14.3336 - val_accuracy: 0.6595
#  Epoch 244/500
#  [==============================] - 424s 9s/step - loss: 0.0197 - accuracy: 0.9984 - val_loss: 0.3972 - val_accuracy: 0.9523
#  Epoch 245/500
#  [==============================] - 421s 9s/step - loss: 0.0117 - accuracy: 0.9996 - val_loss: 6.9564 - val_accuracy: 0.6820
#  Epoch 246/500
#  [==============================] - 421s 9s/step - loss: 0.0101 - accuracy: 0.9995 - val_loss: 1.3520 - val_accuracy: 0.8897
#  Epoch 247/500
#  [==============================] - 420s 9s/step - loss: 0.0106 - accuracy: 0.9993 - val_loss: 1.4798 - val_accuracy: 0.8581
#  Epoch 248/500
#  [==============================] - 427s 10s/step - loss: 0.0094 - accuracy: 0.9998 - val_loss: 12.6114 - val_accuracy: 0.6587
#  Epoch 249/500
#  [==============================] - 426s 9s/step - loss: 0.0085 - accuracy: 0.9996 - val_loss: 9.1215 - val_accuracy: 0.6809
#  Epoch 250/500
#  [==============================] - 421s 9s/step - loss: 0.0145 - accuracy: 0.9979 - val_loss: 143.8004 - val_accuracy: 0.3409
#  Epoch 251/500
#  [==============================] - 429s 10s/step - loss: 0.0158 - accuracy: 0.9990 - val_loss: 16.1832 - val_accuracy: 0.6647
#  Epoch 252/500
#  [==============================] - 415s 9s/step - loss: 0.0223 - accuracy: 0.9979 - val_loss: 32.9083 - val_accuracy: 0.5191
#  Epoch 253/500
#  [==============================] - 411s 9s/step - loss: 0.0168 - accuracy: 0.9988 - val_loss: 18.1166 - val_accuracy: 0.5495
#  Epoch 254/500
#  [==============================] - 416s 9s/step - loss: 0.0119 - accuracy: 0.9995 - val_loss: 20.0022 - val_accuracy: 0.5905
#  Epoch 255/500
#  [==============================] - 411s 9s/step - loss: 0.0088 - accuracy: 0.9997 - val_loss: 9.0289 - val_accuracy: 0.6649
#  Epoch 256/500
#  [==============================] - 410s 9s/step - loss: 0.0067 - accuracy: 0.9999 - val_loss: 4.4364 - val_accuracy: 0.7368
#  Epoch 257/500
#  [==============================] - 417s 9s/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.1910 - val_accuracy: 0.9771
#  Epoch 258/500
#  [==============================] - 410s 9s/step - loss: 0.0075 - accuracy: 0.9992 - val_loss: 11.2836 - val_accuracy: 0.4936
#  Epoch 259/500
#  [==============================] - 415s 9s/step - loss: 0.0134 - accuracy: 0.9989 - val_loss: 30.0504 - val_accuracy: 0.5864
#  Epoch 260/500
#  [==============================] - 410s 9s/step - loss: 0.0101 - accuracy: 0.9996 - val_loss: 0.6257 - val_accuracy: 0.9236
#  Epoch 261/500
#  [==============================] - 414s 9s/step - loss: 0.0120 - accuracy: 0.9992 - val_loss: 14.3333 - val_accuracy: 0.6257
#  Epoch 262/500
#  [==============================] - 415s 9s/step - loss: 0.0110 - accuracy: 0.9993 - val_loss: 7.1387 - val_accuracy: 0.6807
#  Epoch 263/500
#  [==============================] - 416s 9s/step - loss: 0.0095 - accuracy: 0.9996 - val_loss: 1.7983 - val_accuracy: 0.8572
#  Epoch 264/500
#  [==============================] - 415s 9s/step - loss: 0.0231 - accuracy: 0.9978 - val_loss: 5.7111 - val_accuracy: 0.7053
#  Epoch 265/500
#  [==============================] - 415s 9s/step - loss: 0.0184 - accuracy: 0.9989 - val_loss: 0.2459 - val_accuracy: 0.9700
#  Epoch 266/500
#  [==============================] - 410s 9s/step - loss: 0.0117 - accuracy: 0.9998 - val_loss: 0.1656 - val_accuracy: 0.9768
#  Epoch 267/500
#  [==============================] - 410s 9s/step - loss: 0.0083 - accuracy: 0.9997 - val_loss: 3.6620 - val_accuracy: 0.7581
#  Epoch 268/500
#  [==============================] - 411s 9s/step - loss: 0.0075 - accuracy: 0.9997 - val_loss: 1.0238 - val_accuracy: 0.8901
#  Epoch 269/500
#  [==============================] - 413s 9s/step - loss: 0.0076 - accuracy: 0.9999 - val_loss: 0.2992 - val_accuracy: 0.9573
#  Epoch 270/500
#  [==============================] - 412s 9s/step - loss: 0.0069 - accuracy: 0.9997 - val_loss: 0.3462 - val_accuracy: 0.9551
#  Epoch 271/500
#  [==============================] - 415s 9s/step - loss: 0.0055 - accuracy: 0.9999 - val_loss: 0.6520 - val_accuracy: 0.9417
#  Epoch 272/500
#  [==============================] - 413s 9s/step - loss: 0.0068 - accuracy: 0.9995 - val_loss: 12.8349 - val_accuracy: 0.6644
#  Epoch 273/500
#  [==============================] - 411s 9s/step - loss: 0.0161 - accuracy: 0.9978 - val_loss: 5.3106 - val_accuracy: 0.6751
#  Epoch 274/500
#  [==============================] - 412s 9s/step - loss: 0.0249 - accuracy: 0.9977 - val_loss: 1.8151 - val_accuracy: 0.8233
#  Epoch 275/500
#  [==============================] - 412s 9s/step - loss: 0.0176 - accuracy: 0.9996 - val_loss: 1.0546 - val_accuracy: 0.9071
#  Epoch 276/500
#  [==============================] - 411s 9s/step - loss: 0.0140 - accuracy: 0.9995 - val_loss: 5.4361 - val_accuracy: 0.7043
#  Epoch 277/500
#  [==============================] - 413s 9s/step - loss: 0.0155 - accuracy: 0.9993 - val_loss: 14.3636 - val_accuracy: 0.6277
#  Epoch 278/500
#  [==============================] - 415s 9s/step - loss: 0.0108 - accuracy: 0.9997 - val_loss: 7.4025 - val_accuracy: 0.6307
#  Epoch 279/500
#  [==============================] - 414s 9s/step - loss: 0.0083 - accuracy: 0.9997 - val_loss: 0.6287 - val_accuracy: 0.9327
#  Epoch 280/500
#  [==============================] - 412s 9s/step - loss: 0.0073 - accuracy: 0.9995 - val_loss: 2.3816 - val_accuracy: 0.7888
#  Epoch 281/500
#  [==============================] - 417s 9s/step - loss: 0.0133 - accuracy: 0.9985 - val_loss: 9.0043 - val_accuracy: 0.5588
#  Epoch 282/500
#  [==============================] - 408s 9s/step - loss: 0.0185 - accuracy: 0.9990 - val_loss: 0.1935 - val_accuracy: 0.9743
#  Epoch 283/500
#  [==============================] - 411s 9s/step - loss: 0.0109 - accuracy: 0.9998 - val_loss: 0.2166 - val_accuracy: 0.9721
#  Epoch 284/500
#  [==============================] - 409s 9s/step - loss: 0.0091 - accuracy: 0.9995 - val_loss: 0.2329 - val_accuracy: 0.9643
#  Epoch 285/500
#  [==============================] - 411s 9s/step - loss: 0.0095 - accuracy: 0.9993 - val_loss: 12.3184 - val_accuracy: 0.6708
#  Epoch 286/500
#  [==============================] - 409s 9s/step - loss: 0.0111 - accuracy: 0.9995 - val_loss: 5.8550 - val_accuracy: 0.6995
#  Epoch 287/500
#  [==============================] - 419s 9s/step - loss: 0.0108 - accuracy: 0.9997 - val_loss: 28.9328 - val_accuracy: 0.6223
#  Epoch 288/500
#  [==============================] - 411s 9s/step - loss: 0.0106 - accuracy: 0.9993 - val_loss: 4.2352 - val_accuracy: 0.7473
#  Epoch 289/500
#  [==============================] - 411s 9s/step - loss: 0.0075 - accuracy: 0.9997 - val_loss: 1.3421 - val_accuracy: 0.8685
#  Epoch 290/500
#  [==============================] - 412s 9s/step - loss: 0.0066 - accuracy: 0.9999 - val_loss: 7.5568 - val_accuracy: 0.6815
#  Epoch 291/500
#  [==============================] - 419s 9s/step - loss: 0.0180 - accuracy: 0.9989 - val_loss: 1.6183 - val_accuracy: 0.8189
#  Epoch 292/500
#  [==============================] - 416s 9s/step - loss: 0.0206 - accuracy: 0.9980 - val_loss: 1.6654 - val_accuracy: 0.8135
#  Epoch 293/500
#  [==============================] - 411s 9s/step - loss: 0.0234 - accuracy: 0.9982 - val_loss: 0.2804 - val_accuracy: 0.9699
#  Epoch 294/500
#  [==============================] - 413s 9s/step - loss: 0.0159 - accuracy: 0.9995 - val_loss: 1.6001 - val_accuracy: 0.8845
#  Epoch 295/500
#  [==============================] - 414s 9s/step - loss: 0.0116 - accuracy: 0.9996 - val_loss: 0.4650 - val_accuracy: 0.9497
#  Epoch 296/500
#  [==============================] - 414s 9s/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.1563 - val_accuracy: 0.9783
#  Epoch 297/500
#  [==============================] - 413s 9s/step - loss: 0.0060 - accuracy: 0.9999 - val_loss: 0.9676 - val_accuracy: 0.8848
#  Epoch 298/500
#  [==============================] - 413s 9s/step - loss: 0.0051 - accuracy: 0.9999 - val_loss: 0.8490 - val_accuracy: 0.8980
#  Epoch 299/500
#  [==============================] - 411s 9s/step - loss: 0.0076 - accuracy: 0.9996 - val_loss: 7.2097 - val_accuracy: 0.6983
#  Epoch 300/500
#  [==============================] - 421s 9s/step - loss: 0.0094 - accuracy: 0.9992 - val_loss: 0.2493 - val_accuracy: 0.9687
#  Epoch 301/500
#  [==============================] - 412s 9s/step - loss: 0.0091 - accuracy: 0.9995 - val_loss: 5.5389 - val_accuracy: 0.7188
#  Epoch 302/500
#  [==============================] - 414s 9s/step - loss: 0.0181 - accuracy: 0.9982 - val_loss: 13.7821 - val_accuracy: 0.6013
#  Epoch 303/500
#  [==============================] - 415s 9s/step - loss: 0.0144 - accuracy: 0.9996 - val_loss: 0.9251 - val_accuracy: 0.9189
#  Epoch 304/500
#  [==============================] - 417s 9s/step - loss: 0.0128 - accuracy: 0.9992 - val_loss: 11.2200 - val_accuracy: 0.5748
#  Epoch 305/500
#  [==============================] - 418s 9s/step - loss: 0.0112 - accuracy: 0.9996 - val_loss: 3.2839 - val_accuracy: 0.7591
#  Epoch 306/500
#  [==============================] - 420s 9s/step - loss: 0.0102 - accuracy: 0.9998 - val_loss: 1.7968 - val_accuracy: 0.8397
#  Epoch 307/500
#  [==============================] - 428s 10s/step - loss: 0.0082 - accuracy: 0.9996 - val_loss: 7.5395 - val_accuracy: 0.5831
#  Epoch 308/500
#  [==============================] - 445s 10s/step - loss: 0.0098 - accuracy: 0.9993 - val_loss: 4.5805 - val_accuracy: 0.7325
#  Epoch 309/500
#  [==============================] - 442s 10s/step - loss: 0.0119 - accuracy: 0.9991 - val_loss: 5.1833 - val_accuracy: 0.6780
#  Epoch 310/500
#  [==============================] - 444s 10s/step - loss: 0.0133 - accuracy: 0.9991 - val_loss: 79.3475 - val_accuracy: 0.3409
#  Epoch 311/500
#  [==============================] - 448s 10s/step - loss: 0.0111 - accuracy: 0.9996 - val_loss: 1.7409 - val_accuracy: 0.8813
#  Epoch 312/500
#  [==============================] - 452s 10s/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.4324 - val_accuracy: 0.9541
#  Epoch 313/500
#  [==============================] - 454s 10s/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.9926 - val_accuracy: 0.9052
#  Epoch 314/500
#  [==============================] - 446s 10s/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.3339 - val_accuracy: 0.9541
#  Epoch 315/500
#  [==============================] - 453s 10s/step - loss: 0.0041 - accuracy: 0.9998 - val_loss: 3.6459 - val_accuracy: 0.7427
#  Epoch 316/500
#  [==============================] - 444s 10s/step - loss: 0.0069 - accuracy: 0.9993 - val_loss: 25.4286 - val_accuracy: 0.6107
#  Epoch 317/500
#  [==============================] - 451s 10s/step - loss: 0.0117 - accuracy: 0.9990 - val_loss: 4.6871 - val_accuracy: 0.7249
#  Epoch 318/500
#  [==============================] - 454s 10s/step - loss: 0.0148 - accuracy: 0.9989 - val_loss: 13.7113 - val_accuracy: 0.6607
#  Epoch 319/500
#  [==============================] - 443s 10s/step - loss: 0.0226 - accuracy: 0.9981 - val_loss: 8.6119 - val_accuracy: 0.6639
#  Epoch 320/500
#  [==============================] - 448s 10s/step - loss: 0.0186 - accuracy: 0.9989 - val_loss: 6.6219 - val_accuracy: 0.6671
#  Epoch 321/500
#  [==============================] - 447s 10s/step - loss: 0.0182 - accuracy: 0.9989 - val_loss: 30.9927 - val_accuracy: 0.3925
#  Epoch 322/500
#  [==============================] - 454s 10s/step - loss: 0.0160 - accuracy: 0.9991 - val_loss: 3.8128 - val_accuracy: 0.7433
#  Epoch 323/500
#  [==============================] - 442s 10s/step - loss: 0.0131 - accuracy: 0.9994 - val_loss: 10.7012 - val_accuracy: 0.6593
#  Epoch 324/500
#  [==============================] - 447s 10s/step - loss: 0.0097 - accuracy: 0.9997 - val_loss: 6.5190 - val_accuracy: 0.6759
#  Epoch 325/500
#  [==============================] - 455s 10s/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 2.2155 - val_accuracy: 0.8105
#  Epoch 326/500
#  [==============================] - 450s 10s/step - loss: 0.0055 - accuracy: 0.9997 - val_loss: 2.0583 - val_accuracy: 0.8467
#  Epoch 327/500
#  [==============================] - 449s 10s/step - loss: 0.0070 - accuracy: 0.9995 - val_loss: 49.1431 - val_accuracy: 0.3409
#  Epoch 328/500
#  [==============================] - 453s 10s/step - loss: 0.0086 - accuracy: 0.9992 - val_loss: 0.3491 - val_accuracy: 0.9668
#  Epoch 329/500
#  [==============================] - 447s 10s/step - loss: 0.0192 - accuracy: 0.9988 - val_loss: 21.4537 - val_accuracy: 0.5460
#  Epoch 330/500
#  [==============================] - 444s 10s/step - loss: 0.0165 - accuracy: 0.9991 - val_loss: 12.3938 - val_accuracy: 0.6496
#  Epoch 331/500
#  [==============================] - 447s 10s/step - loss: 0.0138 - accuracy: 0.9996 - val_loss: 23.0744 - val_accuracy: 0.5865
#  Epoch 332/500
#  [==============================] - 449s 10s/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 2.2980 - val_accuracy: 0.8489
#  Epoch 333/500
#  [==============================] - 449s 10s/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 2.8544 - val_accuracy: 0.8029
#  Epoch 334/500
#  [==============================] - 441s 10s/step - loss: 0.0053 - accuracy: 0.9999 - val_loss: 4.3800 - val_accuracy: 0.6745
#  Epoch 335/500
#  [==============================] - 448s 10s/step - loss: 0.0082 - accuracy: 0.9995 - val_loss: 0.6191 - val_accuracy: 0.9236
#  Epoch 336/500
#  [==============================] - 450s 10s/step - loss: 0.0095 - accuracy: 0.9994 - val_loss: 3.0845 - val_accuracy: 0.7583
#  Epoch 337/500
#  [==============================] - 445s 10s/step - loss: 0.0087 - accuracy: 0.9996 - val_loss: 9.3946 - val_accuracy: 0.6768
#  Epoch 338/500
#  [==============================] - 442s 10s/step - loss: 0.0087 - accuracy: 0.9995 - val_loss: 8.9457 - val_accuracy: 0.6717
#  Epoch 339/500
#  [==============================] - 445s 10s/step - loss: 0.0087 - accuracy: 0.9996 - val_loss: 5.5446 - val_accuracy: 0.6732
#  Epoch 340/500
#  [==============================] - 448s 10s/step - loss: 0.0163 - accuracy: 0.9987 - val_loss: 5.5132 - val_accuracy: 0.7585
#  Epoch 341/500
#  [==============================] - 446s 10s/step - loss: 0.0161 - accuracy: 0.9986 - val_loss: 5.9666 - val_accuracy: 0.6755
#  Epoch 342/500
#  [==============================] - 448s 10s/step - loss: 0.0242 - accuracy: 0.9976 - val_loss: 19.6434 - val_accuracy: 0.5255
#  Epoch 343/500
#  [==============================] - 451s 10s/step - loss: 0.0181 - accuracy: 0.9990 - val_loss: 1.5995 - val_accuracy: 0.8596
#  Epoch 344/500
#  [==============================] - 454s 10s/step - loss: 0.0134 - accuracy: 0.9994 - val_loss: 1.2774 - val_accuracy: 0.8883
#  Epoch 345/500
#  [==============================] - 448s 10s/step - loss: 0.0103 - accuracy: 0.9996 - val_loss: 0.8063 - val_accuracy: 0.9121
#  Epoch 346/500
#  [==============================] - 442s 10s/step - loss: 0.0079 - accuracy: 0.9998 - val_loss: 4.7921 - val_accuracy: 0.7120
#  Epoch 347/500
#  [==============================] - 460s 10s/step - loss: 0.0087 - accuracy: 0.9996 - val_loss: 0.5790 - val_accuracy: 0.9419
#  Epoch 348/500
#  [==============================] - 450s 10s/step - loss: 0.0079 - accuracy: 0.9997 - val_loss: 0.4608 - val_accuracy: 0.9487
#  Epoch 349/500
#  [==============================] - 447s 10s/step - loss: 0.0080 - accuracy: 0.9997 - val_loss: 17.1968 - val_accuracy: 0.6485
#  Epoch 350/500
#  [==============================] - 445s 10s/step - loss: 0.0198 - accuracy: 0.9980 - val_loss: 16.5944 - val_accuracy: 0.6105
#  Epoch 351/500
#  [==============================] - 448s 10s/step - loss: 0.0178 - accuracy: 0.9993 - val_loss: 27.9238 - val_accuracy: 0.4879
#  Epoch 352/500
#  [==============================] - 450s 10s/step - loss: 0.0130 - accuracy: 0.9998 - val_loss: 22.6305 - val_accuracy: 0.6172
#  Epoch 353/500
#  [==============================] - 446s 10s/step - loss: 0.0140 - accuracy: 0.9991 - val_loss: 1.8740 - val_accuracy: 0.8043
#  Epoch 354/500
#  [==============================] - 444s 10s/step - loss: 0.0134 - accuracy: 0.9992 - val_loss: 2.3254 - val_accuracy: 0.8177
#  Epoch 355/500
#  [==============================] - 448s 10s/step - loss: 0.0111 - accuracy: 0.9996 - val_loss: 2.9405 - val_accuracy: 0.7885
#  Epoch 356/500
#  [==============================] - 443s 10s/step - loss: 0.0075 - accuracy: 0.9999 - val_loss: 19.7995 - val_accuracy: 0.6424

# %% [markdown]
# ## **Use temperature scaling to calibrate the trained CNN with 5,000 simulations per model and perform cross validation predictions with another 5,000 simulations.**

# %%
# Load Numpy test set arrays containing the test set simulations.
u1 = np.load("./testSims/simModel1.npy",mmap_mode='r')
u2 = np.load("./testSims/simModel2.npy",mmap_mode='r')
u3 = np.load("./testSims/simModel3.npy",mmap_mode='r')

# Separate 5,000 simulations for calibration and the remaining 5,000 for cross-validation predictions.
xcal=np.concatenate((u1[0:5000,:,:],u2[0:5000,:,:],u3[0:5000,:,:]),axis=0)
xpred=np.concatenate((u1[5000:10000,:,],u2[5000:10000,:,:],u3[5000:10000,:,:]),axis=0)

# Label each simulated array.
y=[0 for i in range(len(u1[0:5000,:,:]))]
y.extend([1 for i in range(len(u2[0:5000,:,:]))])
y.extend([2 for i in range(len(u3[0:5000,:,:]))])
y = np.array(y)

#delete temporary files to free memory.
del (u1,u2,u3)

# Print label and simulations length, these should be the same.
print (len(xcal), len(xpred), len(y))

# Shuffle the arrays for training, keeping the labels in the same order.
shf = list(range(len(xcal)))
shuffle(shf)
y_shf = y[shf]
xcal = xcal[shf]

# Convert the reference allele to -1.
xcal[xcal == 0] = -1
xpred[xpred == 0] = -1

#Add missing data (coded as 0s) to the simulated matrices (with a percentage according to the empirical data - 15% in E. segueriana).
missD = int(xcal.shape[1]*xcal.shape[2]*.15)
for i in range(xcal.shape[0]):
  for m in range(missD):
    j = random.randint(0, xcal.shape[1] - 1)
    k = random.randint(0, xcal.shape[2] - 1)
    xcal[i][j][k] = 0
del(missD)

missD = int(xpred.shape[1]*xpred.shape[2]*.15)
for i in range(xpred.shape[0]):
  for m in range(missD):
    j = random.randint(0, xpred.shape[1] - 1)
    k = random.randint(0, xpred.shape[2] - 1)
    xpred[i][j][k] = 0
del(missD)

# Split the calibration simulations, 50% for training and 50% for validation.
xtrain, xtest = xcal[int(len(y)*.5):], xcal[:int(len(y)*.5)]
ytrain, ytest = y_shf[int(len(y_shf)*.5):], y_shf[:int(len(y_shf)*.5)]

ytest = np_utils.to_categorical(ytest, num_classes)
ytrain = np_utils.to_categorical(ytrain, num_classes)

#Calibrate the model.
model_score = Model(inputs=model.input, outputs=model.get_layer('logits').output)
X_train_calib = model_score.predict(xtrain)
X_valid_calib = model_score.predict(xtest)
temperature = fit_TemperatureCalibration((X_train_calib,ytrain), (X_valid_calib,ytest), epochs=100)
print ("Temperature",temperature)

# Predict with the calibrated model and export a confusion matrix.
pred_cal = model_score.predict(xpred)
scaled_prediction = cal_softmax(pred_cal/temperature)
scpred_cat = [i.argmax() for i in scaled_prediction]
print (confusion_matrix(y, scpred_cat))
print (confusion_matrix(y, scpred_cat) / float(len(y)))

# Evaluate error and loss for the uncalibrated and calibrated CNN models.
print("Uncalibrated Error %f; loss %f" % evaluate(pred, y, verbose=False, normalize=True))
print("Calibated Error %f; loss %f" % evaluate(scaled_prediction, y, verbose=False, normalize=True))

# Save the 5,000 calibrated predictions per model from the test set, to be used as Summary Statistics in ABC.
np.savetxt("testSet_CalibratedModelPredictions.txt", scaled_prediction)
# Out:
# [[876   0  18   0   0 106   0]
#  [  2 824   0   9   5   0 160]
#  [  0   0 998   2   0   0   0]
#  [  0   1  46 929  23   0   1]
#  [  0   1   0   1 997   0   1]
#  [ 48   0  18   0   0 934   0]
#  [  0  22   2  16   4   1 955]]

# %% [markdown]
# ## **Predict the most likely model for the empirical data, using the calibrated CNN.**

# %%
# Load empirical data.
infile=np.loadtxt("input_Esegueriana.txt")
inp=np.array(infile)

# Create 100 subsets containing 1,000 random SNPs from the full empirical data.
num_samples=100
res = []
for i in range(0,num_samples):
	idx = np.random.choice(inp.shape[0], 1000, replace=False)
	n = inp[idx,:]
	res.append(np.array(n))

Emp = np.array(res)

# Predict model probabilities.
Emp_pred = model_score.predict(Emp)
Emp_pred = cal_softmax(Emp_pred/temperature)

np.savetxt("Emp_ModelPredictions.txt", Emp_pred)
